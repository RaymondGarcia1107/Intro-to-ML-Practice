# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_selector, make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer

# %% [markdown]
# # Loading the data

# %%
path = 'DataFiles/Cereal with missing values.xlsx - Sheet 1 - cereal.csv'
df = pd.read_csv(path)
df.head()
# Out:
#                       name   Manufacturer  type  calories per serving  \
# 0  Apple Cinnamon Cheerios  General Mills  Cold                 110.0
# 1                  Basic 4  General Mills  Cold                 130.0
# 2                 Cheerios  General Mills  Cold                   NaN
# 3    Cinnamon Toast Crunch  General Mills  Cold                 120.0
# 4                 Clusters  General Mills  Cold                 110.0
#
#    grams of protein  grams of fat  milligrams of sodium  \
# 0                 2           2.0                 180.0
# 1                 3           2.0                   NaN
# 2                 6           2.0                 290.0
# 3                 1           3.0                 210.0
# 4                 3           2.0                 140.0
#
#    grams of dietary fiber  grams of complex carbohydrates  grams of sugars  \
# 0                     1.5                            10.5             10.0
# 1                     2.0                            18.0              NaN
# 2                     2.0                            17.0              1.0
# 3                     0.0                            13.0              9.0
# 4                     2.0                            13.0              7.0
#
#    milligrams of potassium  vitamins and minerals (% of FDA recommendation)  \
# 0                       70                                             25.0
# 1                      100                                             25.0
# 2                      105                                             25.0
# 3                       45                                             25.0
# 4                      105                                             25.0
#
#    Display shelf  Weight in ounces per one serving  \
# 0              1                              1.00
# 1              3                              1.33
# 2              1                              1.00
# 3              2                              1.00
# 4              3                              1.00
#
#    Number of cups in one serving  Rating of cereal
# 0                           0.75         29.509541
# 1                           0.75         37.038562
# 2                           1.25         50.764999
# 3                           0.75         19.823573
# 4                           0.50         40.400208

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   name                                             77 non-null     object
#  1   Manufacturer                                     77 non-null     object
#  2   type                                             68 non-null     object
#  3   calories per serving                             70 non-null     float64
#  4   grams of protein                                 77 non-null     int64
#  5   grams of fat                                     69 non-null     float64
#  6   milligrams of sodium                             76 non-null     float64
#  7   grams of dietary fiber                           77 non-null     float64
#  8   grams of complex carbohydrates                   77 non-null     float64
#  9   grams of sugars                                  68 non-null     float64
#  10  milligrams of potassium                          77 non-null     int64
#  11  vitamins and minerals (% of FDA recommendation)  76 non-null     float64
#  12  Display shelf                                    77 non-null     int64
#  13  Weight in ounces per one serving                 77 non-null     float64
#  14  Number of cups in one serving                    77 non-null     float64
#  15  Rating of cereal                                 77 non-null     float64
# dtypes: float64(10), int64(3), object(3)
# memory usage: 9.8+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Whats the question?
# We want to predict calories based on Manufacturer, cereal type, grams of fat, grams of sugar, and weight in ounces per serving
# Lets set up the X and y, but before we do, we need to drop the rows with nulls for calories per serving, since thats our target and we will not impute any missing values here

# %%
df.dropna(subset = ['calories per serving'], inplace = True)
df['calories per serving'].isna().sum()
# Out:
# 0

# %% [markdown]
# All set, now to create our X and y

# %%
X = df[['Manufacturer', 'type', 'grams of fat', 'grams of sugars', 'Weight in ounces per one serving']]
y = df['calories per serving']

X.head()
# Out:
#     Manufacturer  type  grams of fat  grams of sugars  \
# 0  General Mills  Cold           2.0             10.0
# 1  General Mills  Cold           2.0              NaN
# 3  General Mills  Cold           3.0              9.0
# 4  General Mills  Cold           2.0              7.0
# 5  General Mills  Cold           1.0             13.0
#
#    Weight in ounces per one serving
# 0                              1.00
# 1                              1.33
# 3                              1.00
# 4                              1.00
# 5                              1.00

# %% [markdown]
# # Pre-Processing

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70 entries, 0 to 76
# Data columns (total 5 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Manufacturer                      70 non-null     object
#  1   type                              62 non-null     object
#  2   grams of fat                      62 non-null     float64
#  3   grams of sugars                   62 non-null     float64
#  4   Weight in ounces per one serving  70 non-null     float64
# dtypes: float64(3), object(2)
# memory usage: 3.3+ KB

# %% [markdown]
# ## Feature Identification
# We have 2 objects and the rest are floats. we also have some missing values to impute

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
X_train
# Out:
#       Manufacturer  type  grams of fat  grams of sugars  \
# 63     Quaker Oats  Cold           0.0              0.0
# 52            Post   NaN           1.0             12.0
# 18   General Mills  Cold           1.0              3.0
# 37        Kelloggs  Cold           2.0              7.0
# 46         Nabisco   NaN           0.0              0.0
# 31        Kelloggs  Cold           0.0              7.0
# 8    General Mills  Cold           1.0              9.0
# 59     Quaker Oats  Cold           5.0              8.0
# 44        Kelloggs  Cold           0.0              3.0
# 48         Nabisco  Cold           0.0              0.0
# 51            Post  Cold           NaN              NaN
# 21   General Mills  Cold           1.0              8.0
# 62     Quaker Oats  Cold           NaN              NaN
# 43        Kelloggs  Cold           1.0             15.0
# 27        Kelloggs  Cold           NaN              NaN
# 42        Kelloggs   NaN           NaN              3.0
# 15   General Mills  Cold           1.0              3.0
# 55            Post  Cold           0.0              3.0
# 4    General Mills  Cold           2.0              7.0
# 19   General Mills  Cold           1.0              NaN
# 9    General Mills  Cold           1.0             10.0
# 61     Quaker Oats   NaN           2.0             11.0
# 7    General Mills  Cold           1.0             10.0
# 40        Kelloggs  Cold           1.0             12.0
# 71  Ralston Purina   NaN           3.0             11.0
# 76     Quaker Oats   Hot           2.0             -1.0
# 75         Nabisco   Hot           0.0              0.0
# 17   General Mills  Cold           1.0              3.0
# 30        Kelloggs  Cold           0.0             11.0
# 45         Nabisco  Cold           1.0              6.0
# 29        Kelloggs  Cold           1.0             13.0
# 53            Post  Cold           0.0             15.0
# 26        Kelloggs  Cold           0.0             12.0
# 65     Quaker Oats  Cold           1.0              6.0
# 70  Ralston Purina  Cold           3.0             11.0
# 12   General Mills  Cold           1.0              6.0
# 35        Kelloggs  Cold           2.0             13.0
# 73  Ralston Purina  Cold           1.0              3.0
# 68  Ralston Purina  Cold           0.0              3.0
# 41        Kelloggs  Cold           0.0              6.0
# 32        Kelloggs  Cold           0.0             12.0
# 47         Nabisco  Cold           0.0              0.0
# 72  Ralston Purina  Cold           NaN              2.0
# 1    General Mills  Cold           2.0              NaN
# 57            Post  Cold           0.0             11.0
# 23        Kelloggs  Cold           0.0              0.0
# 3    General Mills  Cold           3.0              9.0
# 25        Kelloggs  Cold           0.0              2.0
# 22        Kelloggs  Cold           1.0              NaN
# 66  Ralston Purina  Cold           2.0              8.0
# 16   General Mills  Cold           1.0             14.0
# 56            Post  Cold           3.0              4.0
#
#     Weight in ounces per one serving
# 63                              0.50
# 52                              1.00
# 18                              1.00
# 37                              1.33
# 46                              0.83
# 31                              1.00
# 8                               1.00
# 59                              1.00
# 44                              1.00
# 48                              1.00
# 51                              1.25
# 21                              1.00
# 62                              1.00
# 43                              1.00
# 27                              1.00
# 42                              1.00
# 15                              1.00
# 55                              1.00
# 4                               1.00
# 19                              1.00
# 9                               1.00
# 61                              1.00
# 7                               1.00
# 40                              1.33
# 71                              1.00
# 76                              1.00
# 75                              1.00
# 17                              1.00
# 30                              1.00
# 45                              1.00
# 29                              1.00
# 53                              1.00
# 26                              1.00
# 65                              1.00
# 70                              1.00
# 12                              1.00
# 35                              1.50
# 73                              1.00
# 68                              1.00
# 41                              1.00
# 32                              1.33
# 47                              1.00
# 72                              1.00
# 1                               1.33
# 57                              1.00
# 23                              1.00
# 3                               1.00
# 25                              1.00
# 22                              1.00
# 66                              1.00
# 16                              1.50
# 56                              1.00

# %% [markdown]
# ## Creating my Instances
# To be used later in the transformers

# %%
# Creating the Column Selectors
num_selector = make_column_selector(dtype_include = 'number')
cat_selector = make_column_selector(dtype_include = 'object')

# Creating the Imputers:
mean_imputer = SimpleImputer(strategy = 'mean')
freq_imputer = SimpleImputer(strategy = 'most_frequent')

# Creating the Scaler and OHE:
ohe = OneHotEncoder(sparse = False, handle_unknown = 'ignore')
scaler = StandardScaler()

# %% [markdown]
# ## Combining the Instances

# %%
# Creating the pipelines:
num_pipeline = make_pipeline(mean_imputer, scaler)
cat_pipeline = make_pipeline(freq_imputer, ohe)

# Creating the tuples:
num_tuple = (num_pipeline, num_selector)
cat_tuple = (cat_pipeline, cat_selector)

# Combining into one transformer:
col_transformer = make_column_transformer(num_tuple, cat_tuple, remainder = 'passthrough')

# %% [markdown]
# ## Transforming the data

# %%
col_transformer.fit(X_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer()),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x0000016A2FCF4850>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x0000016A2FCF4A90>)])

# %%
X_train_processed = col_transformer.transform(X_train)
X_test_processed = col_transformer.transform(X_test)

X_train_processed[0:5]
# Out:
# array([[-1.00539366, -1.53835815, -3.52083059,  0.        ,  0.        ,
#          0.        ,  0.        ,  1.        ,  0.        ,  1.        ,
#          0.        ],
#        [-0.04103648,  1.19210391, -0.23976983,  0.        ,  0.        ,
#          0.        ,  1.        ,  0.        ,  0.        ,  1.        ,
#          0.        ],
#        [-0.04103648, -0.85574264, -0.23976983,  1.        ,  0.        ,
#          0.        ,  0.        ,  0.        ,  0.        ,  1.        ,
#          0.        ],
#        [ 0.92332071,  0.05441138,  1.92573028,  0.        ,  1.        ,
#          0.        ,  0.        ,  0.        ,  0.        ,  1.        ,
#          0.        ],
#        [-1.00539366, -1.53835815, -1.35533049,  0.        ,  0.        ,
#          1.        ,  0.        ,  0.        ,  0.        ,  1.        ,
#          0.        ]])

# %% [markdown]
# ## Displaying the data

# %%
print(f'{np.isnan(X_train_processed).sum().sum()} missing values in training data')
print(f'{np.isnan(X_test_processed).sum().sum()} missing values in test data')
print('\n')
print(f'all data in X_train_processed are {X_train_processed.dtype}')
print(f'all data in X_test_processed are {X_test_processed.dtype}')
print('\n')
print(f'shape of training data is {X_train_processed.shape}')
print(f'shape of testing data is {X_test_processed.shape}')
print('\n')
X_train_processed[0:10]
# Out:
# 0 missing values in training data
# 0 missing values in test data
#
#
# all data in X_train_processed are float64
# all data in X_test_processed are float64
#
#
# shape of training data is (52, 11)
# shape of testing data is (18, 11)
# array([[-1.00539366, -1.53835815, -3.52083059,  0.        ,  0.        ,
#          0.        ,  0.        ,  1.        ,  0.        ,  1.        ,
#          0.        ],
#        [-0.04103648,  1.19210391, -0.23976983,  0.        ,  0.        ,
#          0.        ,  1.        ,  0.        ,  0.        ,  1.        ,
#          0.        ],
#        [-0.04103648, -0.85574264, -0.23976983,  1.        ,  0.        ,
#          0.        ,  0.        ,  0.        ,  0.        ,  1.        ,
#          0.        ],
#        [ 0.92332071,  0.05441138,  1.92573028,  0.        ,  1.        ,
#          0.        ,  0.        ,  0.        ,  0.        ,  1.        ,
#          0.        ],
#        [-1.00539366, -1.53835815, -1.35533049,  0.        ,  0.        ,
#          1.        ,  0.        ,  0.        ,  0.        ,  1.        ,
#          0.        ],
#        [-1.00539366,  0.05441138, -0.23976983,  0.        ,  1.        ,
#          0.        ,  0.        ,  0.        ,  0.        ,  1.        ,
#          0.        ],
#        [-0.04103648,  0.50948839, -0.23976983,  1.        ,  0.        ,
#          0.        ,  0.        ,  0.        ,  0.        ,  1.        ,
#          0.        ],
#        [ 3.81639226,  0.28194989, -0.23976983,  0.        ,  0.        ,
#          0.        ,  0.        ,  1.        ,  0.        ,  1.        ,
#          0.        ],
#        [-1.00539366, -0.85574264, -0.23976983,  0.        ,  1.        ,
#          0.        ,  0.        ,  0.        ,  0.        ,  1.        ,
#          0.        ],
#        [-1.00539366, -1.53835815, -0.23976983,  0.        ,  0.        ,
#          1.        ,  0.        ,  0.        ,  0.        ,  1.        ,
#          0.        ]])
